# %%
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/drive']

# The ID of a sample presentation.
PRESENTATION_ID = '1l-rOHVLwhzAj8sLD3M0Lj0Vujw4Z4SboW1ImUDcbExI'

creds = None
# The file token.pickle stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server()
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service_slides = build('slides', 'v1', credentials=creds)
presentation = service_slides.presentations().get(
    presentationId=PRESENTATION_ID).execute()
slides = presentation.get('slides')

service_sheets = build('sheets', 'v4', credentials=creds)
spreadsheet = {
    'properties': {
        'title': "Aroolla Translate"
    }
}
spreadsheet = service_sheets.spreadsheets().create(body=spreadsheet,
                                    fields='spreadsheetId').execute()
print('Spreadsheet ID: {0}'.format(spreadsheet.get('spreadsheetId')))
    
print('The presentation contains {} slides'.format(len(slides)))
# Out:
# Spreadsheet ID: 1Q65jyg9EZUzBtnfX3_Bn22PP9yZS_74tEvim_jHG4xg
# The presentation contains 9 slides

# %%
from google.cloud import translate

translate_client = translate.Client.from_service_account_json('tts.json')

def google_translate(text):
    target = 'en'
    source = 'fr'
    translation = translate_client.translate(text, target_language=target, source_language=source)
    return translation['translatedText']

# %%
ROW_ID = 1
alphabet = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

def write_sheet(values):
    global ROW_ID
    body = {
        'values': [values]
    }
    #print(body)
    service_sheets.spreadsheets().values().update(
        spreadsheetId=spreadsheet.get('spreadsheetId'), range='A{0}:{1}{0}'.format(ROW_ID, alphabet[len(values)-1]),
        valueInputOption='RAW', body=body).execute()
    ROW_ID += 1

# %%
def parse_table(slide_nr, slide_id, element):
    table = element['table']
    for row in table['tableRows']:
        for cell in row['tableCells']:
            try:
                for text_element in cell['text']['textElements']:
                    if 'textRun' in text_element:
                        text = text_element['textRun']['content'].rstrip()
                        if text != "":
                            print(element['objectId'], text)
                            write_sheet([slide_nr, slide_id, element['objectId'], text, google_translate(text)])
            except KeyError:
                pass
        
def parse_shape(slide_nr, slide_id, element):
    try:
        text_elements = element['shape']['text']['textElements']
        for text_element in text_elements:
            if 'textRun' in text_element:
                text = text_element['textRun']['content'].rstrip()
                if text != "":
                    print(element['objectId'], text)
                    write_sheet([slide_nr, slide_id, element['objectId'], text, google_translate(text)])
    except KeyError:
        print(element['shape']['shapeType'])

write_sheet(['slide_nr', 'slide_id', 'object_id', 'original_text', 'translated_text'])

for i, slide in enumerate(slides):
    elements = slide.get('pageElements')
    slide_nr = i + 1
    slide_id = slide['objectId']
    print('- Slide #{} contains {} elements.'.format(
            slide_nr, len(elements)))
    for element in elements:
        if 'shape' in element:
            parse_shape(slide_nr, slide_id, element)
        elif 'table' in element:
            parse_table(slide_nr, slide_id, element)
# Out:
# - Slide #1 contains 3 elements.
# i0 Jeu d’introduction
# TEXT_BOX
# - Slide #2 contains 6 elements.
# g4edb5db6ab_0_12 Objectif de la journée
# g4edb5db6ab_0_13 Découvrir le progiciel de gestion
# g4edb5db6ab_0_13 Connaître les processus métier
# g4edb5db6ab_0_13 Marketing et ventes (campagnes marketing, fixation des prix)
# g4edb5db6ab_0_13 Production (planification)
# g4edb5db6ab_0_13 Approvisionnement (approvisionnement, MRP)
# - Slide #3 contains 3 elements.
# g4edb5db6ab_1_4 Aroolla - La Roasteria
# g4edb5db6ab_1_4 Jeu de simulation d’entreprise
# - Slide #4 contains 9 elements.
# g4edb5db6ab_2_21 75’000 p
# g4edb5db6ab_2_21 0.45/p
# g4edb5db6ab_2_25 1 mio
# g4edb5db6ab_2_25 0.04/p
# g4edb5db6ab_2_25 2.5 mio
# g4edb5db6ab_2_25 0.03/p
# g4edb5db6ab_2_25 7.5 mio
# g4edb5db6ab_2_25 0.02/p
# g4edb5db6ab_2_27 3 jours

# %%
service_drive = build('drive', 'v3', credentials=creds)
body = {
    'name': 'aroolla_roasteria_intro_EN_final'
}
drive_response = service_drive.files().copy(
    fileId=PRESENTATION_ID, body=body).execute()
presentation_copy_id = drive_response.get('id')

# %%
def translate_element(values_dict):
    requests = []
    for values in values_dict:
        requests.append({'replaceAllText': 
                         {'containsText': {'text': values[3], 'matchCase': True}, 
                          'replaceText': values[4],
                          'pageObjectIds': [values[1]]}}
                       )
    body = {
        'requests': requests
    }
    print(requests)
    response = service_slides.presentations().batchUpdate(
        presentationId=presentation_copy_id, body=body).execute()

    num_replacements = 0
    for reply in response.get('replies'):
        try:
            num_replacements += reply.get('replaceAllText').get('occurrencesChanged')
        except:
            pass
    print('Replaced %d text instances' % num_replacements)

# %%
ROW_ID = 2
running = True
values_dict = []
slide_id = None

while running: 
    result = service_sheets.spreadsheets().values().get(
        spreadsheetId=spreadsheet.get('spreadsheetId'), range='A{0}:E{0}'.format(ROW_ID)).execute()
    numRows = result.get('values')
    if numRows:
        values = numRows[0]
        if len(values) == 5:
            if not slide_id:
                slide_id = values[1]
                values_dict.append(values)
            elif slide_id != values[1]:
                translate_element(values_dict)
                slide_id = values[1]
                values_dict = [values]
            else:
                values_dict.append(values)
        ROW_ID += 1
    else:
        translate_element(values_dict)
        running = False
# Out:
# [{'replaceAllText': {'containsText': {'text': 'Jeu d’introduction', 'matchCase': True}, 'replaceText': 'Introductory game', 'pageObjectIds': ['p']}}]
# Replaced 1 text instances
# [{'replaceAllText': {'containsText': {'text': 'Objectif de la journée', 'matchCase': True}, 'replaceText': 'Goal of the day', 'pageObjectIds': ['g4edb5db6ab_0_11']}}, {'replaceAllText': {'containsText': {'text': 'Découvrir le progiciel de gestion', 'matchCase': True}, 'replaceText': 'Discover the management software package', 'pageObjectIds': ['g4edb5db6ab_0_11']}}, {'replaceAllText': {'containsText': {'text': 'Connaître les processus métier', 'matchCase': True}, 'replaceText': 'Know the business processes', 'pageObjectIds': ['g4edb5db6ab_0_11']}}, {'replaceAllText': {'containsText': {'text': 'Marketing et ventes (campagnes marketing, fixation des prix)', 'matchCase': True}, 'replaceText': 'Marketing and sales (marketing campaigns, pricing)', 'pageObjectIds': ['g4edb5db6ab_0_11']}}, {'replaceAllText': {'containsText': {'text': 'Production (planification)', 'matchCase': True}, 'replaceText': 'Production (planning)', 'pageObjectIds': ['g4edb5db6ab_0_11']}}, {'replaceAllText': {'containsText': {'text': 'Approvisionnement (approvisionnement, MRP)', 'matchCase': True}, 'replaceText': 'Procurement (supply, MRP)', 'pageObjectIds': ['g4edb5db6ab_0_11']}}]
# Replaced 6 text instances
# [{'replaceAllText': {'containsText': {'text': 'Aroolla - La Roasteria', 'matchCase': True}, 'replaceText': 'Aroolla - The Roasteria', 'pageObjectIds': ['g4edb5db6ab_1_3']}}, {'replaceAllText': {'containsText': {'text': 'Jeu de simulation d’entreprise', 'matchCase': True}, 'replaceText': 'Business simulation game', 'pageObjectIds': ['g4edb5db6ab_1_3']}}]
# Replaced 2 text instances
# [{'replaceAllText': {'containsText': {'text': 'Pourquoi Aroolla?', 'matchCase': True}, 'replaceText': 'Why Aroolla?', 'pageObjectIds': ['g4edb5db6ab_1_8']}}, {'replaceAllText': {'containsText': {'text': 'Odoo est l’ERP préféré des PME', 'matchCase': True}, 'replaceText': 'Odoo is the preferred ERP of SMEs', 'pageObjectIds': ['g4edb5db6ab_1_8']}}, {'replaceAllText': {'containsText': {'text': 'Scénarios pédagogiques variés', 'matchCase': True}, 'replaceText': 'Various teaching scenarios', 'pageObjectIds': ['g4edb5db6ab_1_8']}}, {'replaceAllText': {'containsText': {'text': 'Flexibilité d’utilisation', 'matchCase': True}, 'replaceText': 'Flexibility of use', 'pageObjectIds': ['g4edb5db6ab_1_8']}}, {'replaceAllText': {'containsText': {'text': 'Pourquoi pas?', 'matchCase': True}, 'replaceText': 'Why not?', 'pageObjectIds': ['g4edb5db6ab_1_8']}}]
# Replaced 5 text instances
# [{'replaceAllText': {'containsText': {'text': 'La Roasteria - Introduction', 'matchCase': True}, 'replaceText': 'The Roasteria - Introduction', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'Fournisseurs', 'matchCase': True}, 'replaceText': 'suppliers', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'Ventes', 'matchCase': True}, 'replaceText': 'Sales', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'automatisé', 'matchCase': True}, 'replaceText': 'automated', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'Achats', 'matchCase': True}, 'replaceText': 'Shopping', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'Production', 'matchCase': True}, 'replaceText': 'Production', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'automatisé', 'matchCase': True}, 'replaceText': 'automated', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'Votre entreprise', 'matchCase': True}, 'replaceText': 'Your company', 'pageObjectIds': ['g4edb5db6ab_1_24']}}, {'replaceAllText': {'containsText': {'text': 'Clients', 'matchCase': True}, 'replaceText': 'customers', 'pageObjectIds': ['g4edb5db6ab_1_24']}}]
# Replaced 9 text instances
# [{'replaceAllText': {'containsText': {'text': 'Votre entreprise', 'matchCase': True}, 'replaceText': 'Your company', 'pageObjectIds': ['g4edb5db6ab_1_92']}}, {'replaceAllText': {'containsText': {'text': 'Chaque équipe\xa0gère une entreprise de production de café', 'matchCase': True}, 'replaceText': 'Each team runs a coffee business', 'pageObjectIds': ['g4edb5db6ab_1_92']}}, {'replaceAllText': {'containsText': {'text': 'Groupe\xa0de 4 managers', 'matchCase': True}, 'replaceText': 'Group of 4 managers', 'pageObjectIds': ['g4edb5db6ab_1_92']}}, {'replaceAllText': {'containsText': {'text': 'Assurer la rentabilité des opérations', 'matchCase': True}, 'replaceText': 'Ensuring the profitability of operations', 'pageObjectIds': ['g4edb5db6ab_1_92']}}, {'replaceAllText': {'containsText': {'text': 'Prendre des décisions', 'matchCase': True}, 'replaceText': 'To take decisions', 'pageObjectIds': ['g4edb5db6ab_1_92']}}, {'replaceAllText': {'containsText': {'text': 'Utiliser\xa0les rapports produits par le système', 'matchCase': True}, 'replaceText': 'Use reports produced by the system', 'pageObjectIds': ['g4edb5db6ab_1_92']}}]
# Replaced 6 text instances
# [{'replaceAllText': {'containsText': {'text': 'Votre entreprise achète des graines de café aux producteurs puis torréfie le café pour le vendre en sacs, paquets et pods.', 'matchCase': True}, 'replaceText': 'Your company buys coffee beans from growers and then roasts coffee for sale in bags, packages and pods.', 'pageObjectIds': ['g4edb5db6ab_1_117']}}, {'replaceAllText': {'containsText': {'text': 'Scénario du jeu la Roasteria', 'matchCase': True}, 'replaceText': 'Scenario of the game Roasteria', 'pageObjectIds': ['g4edb5db6ab_1_117']}}, {'replaceAllText': {'containsText': {'text': 'Ventes', 'matchCase': True}, 'replaceText': 'Sales', 'pageObjectIds': ['g4edb5db6ab_1_117']}}, {'replaceAllText': {'containsText': {'text': 'Achats', 'matchCase': True}, 'replaceText': 'Shopping', 'pageObjectIds': ['g4edb5db6ab_1_117']}}, {'replaceAllText': {'containsText': {'text': 'Production', 'matchCase': True}, 'replaceText': 'Production', 'pageObjectIds': ['g4edb5db6ab_1_117']}}]
# Replaced 5 text instances
# [{'replaceAllText': {'containsText': {'text': 'Votre production', 'matchCase': True}, 'replaceText': 'Your production', 'pageObjectIds': ['g4edb5db6ab_1_38']}}, {'replaceAllText': {'containsText': {'text': '%', 'matchCase': True}, 'replaceText': '%', 'pageObjectIds': ['g4edb5db6ab_1_38']}}, {'replaceAllText': {'containsText': {'text': '%', 'matchCase': True}, 'replaceText': '%', 'pageObjectIds': ['g4edb5db6ab_1_38']}}]
# Replaced 5 text instances
# [{'replaceAllText': {'containsText': {'text': 'Achats', 'matchCase': True}, 'replaceText': 'Shopping', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': 'Production', 'matchCase': True}, 'replaceText': 'Production', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': 'Ventes', 'matchCase': True}, 'replaceText': 'Sales', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '10 t', 'matchCase': True}, 'replaceText': '10 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '8.50/kg', 'matchCase': True}, 'replaceText': '8.50 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '50 t', 'matchCase': True}, 'replaceText': '50 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '7.00/kg', 'matchCase': True}, 'replaceText': '7.00 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '150 t', 'matchCase': True}, 'replaceText': '150 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '5.50/kg', 'matchCase': True}, 'replaceText': '5.50 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '5 t', 'matchCase': True}, 'replaceText': '5 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '7.00/kg', 'matchCase': True}, 'replaceText': '7.00 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '20 t', 'matchCase': True}, 'replaceText': '20 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '5.50/kg', 'matchCase': True}, 'replaceText': '5.50 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '60 t', 'matchCase': True}, 'replaceText': '60 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '4.00/kg', 'matchCase': True}, 'replaceText': '4.00 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '10 t', 'matchCase': True}, 'replaceText': '10 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '10.00/kg', 'matchCase': True}, 'replaceText': '10.00 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '50 t', 'matchCase': True}, 'replaceText': '50 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '8.50/kg', 'matchCase': True}, 'replaceText': '8.50 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '150 t', 'matchCase': True}, 'replaceText': '150 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '7.00/kg', 'matchCase': True}, 'replaceText': '7.00 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '5 t', 'matchCase': True}, 'replaceText': '5 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '8.50/kg', 'matchCase': True}, 'replaceText': '8.50 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '20 t', 'matchCase': True}, 'replaceText': '20 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '7.00/kg', 'matchCase': True}, 'replaceText': '7.00 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '60 t', 'matchCase': True}, 'replaceText': '60 t', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '5.50/kg', 'matchCase': True}, 'replaceText': '5.50 / kg', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAllText': {'containsText': {'text': '4 jours', 'matchCase': True}, 'replaceText': '4 days', 'pageObjectIds': ['g4edb5db6ab_1_247']}}, {'replaceAl ...
# Replaced 64 text instances
